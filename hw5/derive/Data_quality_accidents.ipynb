# %%
#!pip3 install pandas
#!pip3 install pandas-profiling
#!pip3 install matplotlib
#!pip3 install seaborn

# %%
# %matplotlib inline

import matplotlib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_profiling
from pandas_profiling.describe import describe
# Out:
# '\n%matplotlib inline\n\nimport matplotlib\nimport pandas as pd\nimport numpy as np\nimport matplotlib.pyplot as plt\nimport pandas_profiling\nfrom pandas_profiling.describe import describe\n'

# %%
df = pd.read_csv('2017_ACCIDENTES_DE_TR_NSITO_BOGOT_.csv')
df.head()
# Out:
#    Accidente        Día                   Fecha   Oficina  GravedadCod  \
# 0    4480506     SÁBADO  04/29/2017 12:00:00 AM  11001000            2
# 1    4480511  MIÉRCOLES  05/03/2017 12:00:00 AM  11001000            2
# 2    4480666    VIERNES  05/05/2017 12:00:00 AM  11001000            2
# 3    4480721     SÁBADO  05/06/2017 12:00:00 AM  11001000            2
# 4    4480727     SÁBADO  05/06/2017 12:00:00 AM  11001000            2
#
#   GravedadNombre  ClaseCodigo ClaseNombre ChoqueCodigo ChoqueNombre  \
# 0    Con Heridos            2   Atropello
# 1    Con Heridos            1      Choque            1     Vehiculo
# 2    Con Heridos            1      Choque            1     Vehiculo
# 3    Con Heridos            1      Choque            1     Vehiculo
# 4    Con Heridos            1      Choque            1     Vehiculo
#
#        ...       CausaVehiculoIICod CausaVehiculoIIDesc CausaPasajeroICod  \
# 0      ...
# 1      ...
# 2      ...
# 3      ...
# 4      ...
#
#   CausaPasajeroIDesc  CausaPasajeroIICod  CausaPasajeroIIDesc CausaViaICod  \
# 0
# 1
# 2
# 3
# 4
#
#   CausaViaIDesc CausaViaIICod CausaViaIIDesc
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 66 columns]

# %%
df['fecha_oc'] = df['FechaOcurrencia']
df['hora_oc'] = df['HoraOcurrencia']
df['fecha_hora_oc'] = df['FechaOcurrencia'].str[:10] + ' '+ df['HoraOcurrencia'].str[11:]
df['event_time'] = pd.to_datetime(df['fecha_hora_oc'], format='%m/%d/%Y %I:%M:%S %p')
df['event_date'] =  df['event_time'].dt.strftime('%Y-%m-%d')
df['event_hour'] = df['event_time'].dt.strftime('%H')
df['event_day'] = df['event_time'].dt.strftime('%w')
df['event_day_name'] = df['event_time'].dt.strftime('%A')
df['event_month'] = df['event_time'].dt.strftime('%m')
df['event_month_name'] = df['event_time'].dt.strftime('%B')

# %%
df.head(5)
# Out:
#    Accidente        Día                   Fecha   Oficina  GravedadCod  \
# 0    4480506     SÁBADO  04/29/2017 12:00:00 AM  11001000            2
# 1    4480511  MIÉRCOLES  05/03/2017 12:00:00 AM  11001000            2
# 2    4480666    VIERNES  05/05/2017 12:00:00 AM  11001000            2
# 3    4480721     SÁBADO  05/06/2017 12:00:00 AM  11001000            2
# 4    4480727     SÁBADO  05/06/2017 12:00:00 AM  11001000            2
#
#   GravedadNombre  ClaseCodigo ClaseNombre ChoqueCodigo ChoqueNombre  \
# 0    Con Heridos            2   Atropello
# 1    Con Heridos            1      Choque            1     Vehiculo
# 2    Con Heridos            1      Choque            1     Vehiculo
# 3    Con Heridos            1      Choque            1     Vehiculo
# 4    Con Heridos            1      Choque            1     Vehiculo
#
#         ...                       fecha_oc                 hora_oc  \
# 0       ...         04/29/2017 12:00:00 AM  12/31/1899 03:40:00 PM
# 1       ...         05/03/2017 12:00:00 AM  12/31/1899 01:30:00 PM
# 2       ...         05/05/2017 12:00:00 AM  12/31/1899 11:45:00 AM
# 3       ...         05/06/2017 12:00:00 AM  12/31/1899 10:00:00 AM
# 4       ...         05/06/2017 12:00:00 AM  12/31/1899 07:10:00 AM
#
#             fecha_hora_oc          event_time  event_date  event_hour  \
# 0  04/29/2017 03:40:00 PM 2017-04-29 15:40:00  2017-04-29          15
# 1  05/03/2017 01:30:00 PM 2017-05-03 13:30:00  2017-05-03          13
# 2  05/05/2017 11:45:00 AM 2017-05-05 11:45:00  2017-05-05          11
# 3  05/06/2017 10:00:00 AM 2017-05-06 10:00:00  2017-05-06          10
# 4  05/06/2017 07:10:00 AM 2017-05-06 07:10:00  2017-05-06          07
#
#   event_day event_day_name event_month event_month_name
# 0         6       Saturday          04            April
# 1         3      Wednesday          05              May
# 2         5         Friday          05              May
# 3         6       Saturday          05              May
# 4         6       Saturday          05              May
#
# [5 rows x 76 columns]

# %%
df.isnull().sum()
# Out:
# Accidente                0
# Día                      0
# Fecha                    0
# Oficina                  0
# GravedadCod              0
# GravedadNombre           0
# ClaseCodigo              0
# ClaseNombre              0
# ChoqueCodigo             0
# ChoqueNombre             0
# ObjetoFijoCodigo         0
# ObjetoFijoNombre         0
# OtraClase                0
# NombreOtraClase          0
# Latitud                  0
# Longitud                 0
# Direccion                0
# TipoVia1                 0
# NumeroVia1               4
# LetraVia1                0
# CardinalVia1             0
# TipoVia2                 0
# NumeroVia2              20
# LetraVia2                0
# CardinalVia2             0
# Complemento              4
# Municipio                0
# Localidad                0
# FechaOcurrencia          0
# HoraOcurrencia           0
#                         ..
# CausaConductorICo        0
# CausaConductorIDesc      0
# CausaConductorIICod      0
# CausaConductorIIDesc     0
# CausaPeatonICod          0
# CausaPeatonIDesc         0
# CausaPeatonIICod         0
# CausaPeatonIIDesc        0
# CausaVehiculoICod        0
# CausaVehiculoIDesc       0
# CausaVehiculoIICod       0
# CausaVehiculoIIDesc      0
# CausaPasajeroICod        0
# CausaPasajeroIDesc       0
# CausaPasajeroIICod       0
# CausaPasajeroIIDesc      0
# CausaViaICod             0
# CausaViaIDesc            0
# CausaViaIICod            0
# CausaViaIIDesc           0
# fecha_oc                 0
# hora_oc                  0
# fecha_hora_oc            0
# event_time               0
# event_date               0
# event_hour               0
# event_day                0
# event_day_name           0
# event_month              0
# event_month_name         0
# Length: 76, dtype: int64

# %%
df.isnull().sum() / len(df) * 100
# Out:
# Accidente               0.000000
# Día                     0.000000
# Fecha                   0.000000
# Oficina                 0.000000
# GravedadCod             0.000000
# GravedadNombre          0.000000
# ClaseCodigo             0.000000
# ClaseNombre             0.000000
# ChoqueCodigo            0.000000
# ChoqueNombre            0.000000
# ObjetoFijoCodigo        0.000000
# ObjetoFijoNombre        0.000000
# OtraClase               0.000000
# NombreOtraClase         0.000000
# Latitud                 0.000000
# Longitud                0.000000
# Direccion               0.000000
# TipoVia1                0.000000
# NumeroVia1              0.011364
# LetraVia1               0.000000
# CardinalVia1            0.000000
# TipoVia2                0.000000
# NumeroVia2              0.056818
# LetraVia2               0.000000
# CardinalVia2            0.000000
# Complemento             0.011364
# Municipio               0.000000
# Localidad               0.000000
# FechaOcurrencia         0.000000
# HoraOcurrencia          0.000000
#                           ...
# CausaConductorICo       0.000000
# CausaConductorIDesc     0.000000
# CausaConductorIICod     0.000000
# CausaConductorIIDesc    0.000000
# CausaPeatonICod         0.000000
# CausaPeatonIDesc        0.000000
# CausaPeatonIICod        0.000000
# CausaPeatonIIDesc       0.000000
# CausaVehiculoICod       0.000000
# CausaVehiculoIDesc      0.000000
# CausaVehiculoIICod      0.000000
# CausaVehiculoIIDesc     0.000000
# CausaPasajeroICod       0.000000
# CausaPasajeroIDesc      0.000000
# CausaPasajeroIICod      0.000000
# CausaPasajeroIIDesc     0.000000
# CausaViaICod            0.000000
# CausaViaIDesc           0.000000
# CausaViaIICod           0.000000
# CausaViaIIDesc          0.000000
# fecha_oc                0.000000
# hora_oc                 0.000000
# fecha_hora_oc           0.000000
# event_time              0.000000
# event_date              0.000000
# event_hour              0.000000
# event_day               0.000000
# event_day_name          0.000000
# event_month             0.000000
# event_month_name        0.000000
# Length: 76, dtype: float64

# %%
list(df)
# Out:
# ['Accidente',
#  'Día',
#  'Fecha',
#  'Oficina',
#  'GravedadCod',
#  'GravedadNombre',
#  'ClaseCodigo',
#  'ClaseNombre',
#  'ChoqueCodigo',
#  'ChoqueNombre',
#  'ObjetoFijoCodigo',
#  'ObjetoFijoNombre',
#  'OtraClase',
#  'NombreOtraClase',
#  'Latitud',
#  'Longitud',
#  'Direccion',
#  'TipoVia1',
#  'NumeroVia1',
#  'LetraVia1',
#  'CardinalVia1',
#  'TipoVia2',
#  'NumeroVia2',
#  'LetraVia2',
#  'CardinalVia2',
#  'Complemento',
#  'Municipio',
#  'Localidad',
#  'FechaOcurrencia',
#  'HoraOcurrencia',
#  'Area',
#  'Sector',
#  'Zona',
#  'TipoDiseño',
#  'TipoTiempo',
#  'ZonaTransito',
#  'AreaTransito',
#  'CorredorVial',
#  'TotalMuertos',
#  'TotalHeridos',
#  'Correspondio',
#  'CodigoDepartamento',
#  'CodigoMunicipio',
#  'UnidadReceptora',
#  'Año',
#  'Consecutivo',
#  'CausaConductorICo',
#  'CausaConductorIDesc',
#  'CausaConductorIICod',
#  'CausaConductorIIDesc',
#  'CausaPeatonICod',
#  'CausaPeatonIDesc',
#  'CausaPeatonIICod',
#  'CausaPeatonIIDesc',
#  'CausaVehiculoICod',
#  'CausaVehiculoIDesc',
#  'CausaVehiculoIICod',
#  'CausaVehiculoIIDesc',
#  'CausaPasajeroICod',
#  'CausaPasajeroIDesc',
#  'CausaPasajeroIICod',
#  'CausaPasajeroIIDesc',
#  'CausaViaICod',
#  'CausaViaIDesc',
#  'CausaViaIICod',
#  'CausaViaIIDesc',
#  'fecha_oc',
#  'hora_oc',
#  'fecha_hora_oc',
#  'event_time',
#  'event_date',
#  'event_hour',
#  'event_day',
#  'event_day_name',
#  'event_month',
#  'event_month_name']

# %%
# tale of nulls 
# https://towardsdatascience.com/the-tale-of-missing-values-in-python-c96beb0e8a9d
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35200 entries, 0 to 35199
# Data columns (total 76 columns):
# Accidente               35200 non-null int64
# Día                     35200 non-null object
# Fecha                   35200 non-null object
# Oficina                 35200 non-null int64
# GravedadCod             35200 non-null int64
# GravedadNombre          35200 non-null object
# ClaseCodigo             35200 non-null int64
# ClaseNombre             35200 non-null object
# ChoqueCodigo            35200 non-null object
# ChoqueNombre            35200 non-null object
# ObjetoFijoCodigo        35200 non-null object
# ObjetoFijoNombre        35200 non-null object
# OtraClase               35200 non-null object
# NombreOtraClase         35200 non-null object
# Latitud                 35200 non-null float64
# Longitud                35200 non-null float64
# Direccion               35200 non-null object
# TipoVia1                35200 non-null object
# NumeroVia1              35196 non-null object
# LetraVia1               35200 non-null object
# CardinalVia1            35200 non-null object
# TipoVia2                35200 non-null object
# NumeroVia2              35180 non-null float64
# LetraVia2               35200 non-null object
# CardinalVia2            35200 non-null object
# Complemento             35196 non-null float64
# Municipio               35200 non-null object
# Localidad               35200 non-null object
# FechaOcurrencia         35200 non-null object
# HoraOcurrencia          35200 non-null object
# Area                    35200 non-null int64
# Sector                  35200 non-null int64
# Zona                    35200 non-null int64
# TipoDiseño              35200 non-null object
# TipoTiempo              35200 non-null object
# ZonaTransito            35200 non-null object
# AreaTransito            35200 non-null object
# CorredorVial            35200 non-null object
# TotalMuertos            35200 non-null int64
# TotalHeridos            35200 non-null int64
# Correspondio            35200 non-null object
# CodigoDepartamento      35200 non-null object
# CodigoMunicipio         35200 non-null object
# UnidadReceptora         0 non-null float64
# Año                     35200 non-null int64
# Consecutivo             35147 non-null float64
# CausaConductorICo       35200 non-null object
# CausaConductorIDesc     35200 non-null object
# CausaConductorIICod     35200 non-null object
# CausaConductorIIDesc    35200 non-null object
# CausaPeatonICod         35200 non-null object
# CausaPeatonIDesc        35200 non-null object
# CausaPeatonIICod        35200 non-null object
# CausaPeatonIIDesc       35200 non-null object
# CausaVehiculoICod       35200 non-null object
# CausaVehiculoIDesc      35200 non-null object
# CausaVehiculoIICod      35200 non-null object
# CausaVehiculoIIDesc     35200 non-null object
# CausaPasajeroICod       35200 non-null object
# CausaPasajeroIDesc      35200 non-null object
# CausaPasajeroIICod      35200 non-null object
# CausaPasajeroIIDesc     35200 non-null object
# CausaViaICod            35200 non-null object
# CausaViaIDesc           35200 non-null object
# CausaViaIICod           35200 non-null object
# CausaViaIIDesc          35200 non-null object
# fecha_oc                35200 non-null object
# hora_oc                 35200 non-null object
# fecha_hora_oc           35200 non-null object
# event_time              35200 non-null datetime64[ns]
# event_date              35200 non-null object
# event_hour              35200 non-null object
# event_day               35200 non-null object
# event_day_name          35200 non-null object
# event_month             35200 non-null object
# event_month_name        35200 non-null object
# dtypes: datetime64[ns](1), float64(6), int64(10), object(59)
# memory usage: 20.4+ MB

# %%
#describe(df, check_correlation=False)
pandas_profiling.ProfileReport(df)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>76 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>35200 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>1.3% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>20.4 MiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>608.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>12 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>53 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>9 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_Año"><code>Año</code></a> has constant value 2017 <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_CausaConductorICo"><code>CausaConductorICo</code></a> has a high cardinality: 64 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_CausaConductorIDesc"><code>CausaConductorIDesc</code></a> has a high cardinality: 64 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_CausaConductorIICod"><code>CausaConductorIICod</code></a> has a high cardinality: 58 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_CausaConductorIIDesc"><code>CausaConductorIIDesc</code></a> has a high cardinality: 58 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_CausaPasajeroIICod"><code>CausaPasajeroIICod</code></a> has constant value   <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_CausaPasajeroIIDesc"><code>CausaPasajeroIIDesc</code></a> has constant value   <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_CodigoDepartamento"><code>CodigoDepartamento</code></a> has constant value

# %% [markdown]
# # graphics

# %%
df_date = df[['event_date']].groupby(['event_date'])['event_date'] \
                             .count() \
                             .reset_index(name='count') \
                             .sort_values(['event_date'], ascending=True) \

# %%
import seaborn as sns
sns.set(style="darkgrid")

plt.subplots(figsize=(20,10))
# Plot the responses for different events and regions
sns.lineplot(x="event_date", y="count",
             data=df_date)

# %%
df_date.head(10)
# Out:
#    event_date  count
# 0  2017-01-01     35
# 1  2017-01-02     41
# 2  2017-01-03     80
# 3  2017-01-04     53
# 4  2017-01-05     70
# 5  2017-01-06     67
# 6  2017-01-07     56
# 7  2017-01-08     29
# 8  2017-01-09     45
# 9  2017-01-10     76

# %% [markdown]
# # Export filtered columns  for visualization

# %%
df1 = df[['event_time', 'event_date', 'event_hour', 'event_day','event_day_name','event_month', 'event_month_name',
          'GravedadNombre', 'ClaseNombre', 'ChoqueNombre', 'ObjetoFijoNombre',
 'Localidad',
 'TipoDiseño',
 'TipoTiempo',
 'CorredorVial',
 'TotalMuertos',
 'TotalHeridos',
 'CausaConductorIDesc',
 'CausaConductorIIDesc',
 'CausaPeatonIDesc',
 'CausaPeatonIIDesc',
 'CausaVehiculoIDesc',
 'CausaVehiculoIIDesc',
 'CausaPasajeroIDesc',
 'CausaViaIDesc',
 'CausaViaIIDesc']]

df1.head()
# Out:
#            event_time  event_date event_hour event_day event_day_name  \
# 0 2017-04-29 15:40:00  2017-04-29         15         6       Saturday
# 1 2017-05-03 13:30:00  2017-05-03         13         3      Wednesday
# 2 2017-05-05 11:45:00  2017-05-05         11         5         Friday
# 3 2017-05-06 10:00:00  2017-05-06         10         6       Saturday
# 4 2017-05-06 07:10:00  2017-05-06         07         6       Saturday
#
#   event_month event_month_name GravedadNombre ClaseNombre ChoqueNombre  \
# 0          04            April    Con Heridos   Atropello
# 1          05              May    Con Heridos      Choque     Vehiculo
# 2          05              May    Con Heridos      Choque     Vehiculo
# 3          05              May    Con Heridos      Choque     Vehiculo
# 4          05              May    Con Heridos      Choque     Vehiculo
#
#        ...       TotalHeridos                 CausaConductorIDesc  \
# 0      ...                  2
# 1      ...                  2                 DESOBEDECER SEÑALES
# 2      ...                  1                                OTRA
# 3      ...                  1  NO MANTENER DISTANCIA DE SEGURIDAD
# 4      ...                  3                 DESOBEDECER SEÑALES
#
#   CausaConductorIIDesc     CausaPeatonIDesc CausaPeatonIIDesc  \
# 0                       CRUZAR SIN OBSERVAR
# 1  DESOBEDECER SEÑALES
# 2
# 3
# 4
#
#    CausaVehiculoIDesc  CausaVehiculoIIDesc CausaPasajeroIDesc CausaViaIDesc  \
# 0
# 1
# 2
# 3
# 4
#
#   CausaViaIIDesc
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 26 columns]

# %%
#df1.to_csv("accidentes_bta.tsv", sep='\t', encoding='utf-8', index=False)
df1.to_csv("accidentes_bta.csv",  encoding='utf-8', index=False)

# %%
pandas_profiling.ProfileReport(df1)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>26 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>35200 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>0.0% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>7.0 MiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>208.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>2 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>23 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_CausaConductorIDesc"><code>CausaConductorIDesc</code></a> has a high cardinality: 64 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_CausaConductorIIDesc"><code>CausaConductorIIDesc</code></a> has a high cardinality: 58 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_TotalHeridos"><code>TotalHeridos</code></a> has 24673 / 70.1% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_TotalMuertos"><code>TotalMuertos</code></a> has 34667 / 98.5% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_event_date"><code>event_date</code></a> has a high cardinality: 365 distinct values  <span class="label label-warning">Warning</span></li><li>Dataset has 21 duplicate rows <span class="label label-warning">Warning</span></li> </ul>
#     </div>
# </div>
#     <div class="row headerrow highlight">
#         <h1>Variables</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-3 namecol">
#         <p class="h4 pp-anchor" id="pp_var_CausaConductorIDesc">CausaConductorIDesc<br/>
#             <small>Categorical</small>
#         </p>
#     </div><div class="col-md-3">
#     <tabl
